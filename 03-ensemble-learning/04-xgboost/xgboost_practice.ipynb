# %% [markdown]
# # 🌲 XGBoost — Practice Notebook
#
# **Difficulty**: ⭐⭐⭐ Advanced
# **Time**: ~50 mins
# **Guided exercise — implement the # TODO blocks.**
#
# ---

# %% [markdown]
# ## 🎯 Section 1: Overview
#
# XGBoost is an optimized Gradient Boosting framework using 2nd-order Taylor expansions, L1/L2 tree regularization, and hardware parallelism.
#
# ### Taylor Expansion Objective:
# $$\mathcal{L}^{(t)} \approx \sum_{i=1}^n \left[ g_i f_t(x_i) + \frac{1}{2} h_i f_t^2(x_i) \right] + \gamma T + \frac{1}{2} \lambda \sum w_j^2$$

# %% [markdown]
# ## 🔧 Section 2: Implementation from Scratch

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

print('Setup complete! ✅')

# %%
# Explore XGBoost implementation and hyperparameter optimization
# TODO: Implement XGBoost Classifier with early stopping and evaluation sets

# %% [markdown]
# ## 📦 Section 3: Library Implementation

# %%
import xgboost as xgb
model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
model.fit(X_train, y_train)

# %% [markdown]
# ## ❓ Section 4: Interview Questions

# %% [markdown]
# ### Q1: What makes XGBoost faster and more accurate than traditional GBM?
# **Answer**: Second-order Taylor expansion (incorporates curvature via Hessian), built-in L1/L2 regularization, weighted quantile sketch for split finding, cache awareness, and parallel column block processing.

# %% [markdown]
# ### Q2: What are gamma, alpha, and lambda in XGBoost?
# **Answer**: Gamma (min split loss reduction threshold), Alpha (L1 regularization on leaf weights), Lambda (L2 regularization on leaf weights).
